# %% [markdown]
# # 🚀 Talent Arena 2026
# # Building a Tech Trend Discovery Agent
#
# ## Welcome to the AI Agents Workshop!
#
# <img src="https://img.shields.io/badge/MWC-2026-blue" /> <img src="https://img.shields.io/badge/Track-Tech_Trends-green" /> <img src="https://img.shields.io/badge/Duration-90min-orange" />
#
# ---
#
# ### What You'll Build Today
#
# A **Tech Trend Discovery Agent** that given a particular topic:
# - 🔥 Scrapes trending projects from Hacker News
# - 📊 Analyzes project popularity and discussions
# - 🔍 Gathers detailed information about technologies
# - 🤖 Uses the ReAct pattern for transparent reasoning
# - ✅ Performs each step of the workflow correctly and in order
#
# ---
#
# ### What You'll Learn
#
# - 🧠 **How AI Agents Work** — Beyond simple chatbots
# - 🔄 **The ReAct Pattern** — Reasoning + Acting in loops
# - 🛠️ **Tool Integration** — Giving agents real-world capabilities
# - ✏️ **Prompt Engineering** — The art of steering agent behavior

# %% [markdown]
# ---
#
# ## 📦 Part 1: Quick Setup
#
# We'll install everything you need in one go. This takes about 60 seconds.

# %%
# 🔧 Automated Setup - Run this cell first!

import sys

# Download requirements and framework from GitHub
print("1️⃣ Downloading workshop files...")
# !wget -O requirements.txt -q https://raw.githubusercontent.com/Sage/talent-arena-2026/master/requirements.txt
# !wget -O lab.py -q https://raw.githubusercontent.com/Sage/talent-arena-2026/master/lab.py
# !wget -O session_1_agent_optimization.py -q https://raw.githubusercontent.com/Sage/talent-arena-2026/master/session_1_agent_optimization.py

print("\n2️⃣ Installing Python packages (this may take 30-60 seconds)...")
# !pip install --upgrade pip --quiet
# !pip install -r requirements.txt --quiet

print("✅ Setup complete! You're ready to build agents!")
# Out:
# 1️⃣ Downloading workshop files...
#
# 2️⃣ Installing Python packages (this may take 30-60 seconds)...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.6 MB/s eta 0:00:00
# ✅ Setup complete! You're ready to build agents!

# %% [markdown]
# ---
#
# ## ⚙️ Configure Your LLM Connection
#
# Before we begin, you need to store two secrets so the notebook can talk to the LLM backend.
#
# **📝 In Google Colab → click the 🔑 icon on the left sidebar → add:**
#
# | Secret name | Value |
# |-------------|-------|
# | `LLM_SERVICE_URL` | The URL provided by the workshop facilitator |
# | `PASSWORD` | The password provided by the workshop facilitator |

# %%
from google.colab import userdata
import os

key = userdata.get('LLM_SERVICE_URL')
password = userdata.get('PASSWORD')

if key and password:
    os.environ['LLM_SERVICE_URL'] = key
    os.environ['PASSWORD'] = password
    print("✅ API key and password configured from Colab userdata!")
else:
    print("⚠️ API key or password not found in Colab userdata. Please set them manually as environment variables.")
# Out:
# ✅ API key and password configured from Colab userdata!

# %% [markdown]
# ---
#
# ## 🧪 Quick Verification
#
# Let's verify everything is working by testing the framework and tools.

# %%
# 🧪 Quick Verification

try:
    from lab import BaseAgent, Tools, test_all_tools
    print("\n🔬 Testing tools...\n")
    test_all_tools(verbose=True)
except Exception as e:
    print(f"❌ Something went wrong: {e}")
    print("💡 Re-run the setup cells above and try again.")
# Out:
# 🔬 Testing tools...
#
# 🧪 Testing All Tools
# ======================================================================
#
# ✅ get_stock_price('AAPL')
#    Price: $272.95 (-0.73%)
# WARNING:primp.impersonate:Impersonate 'chrome_130' does not exist, using 'random'
# ✅ search_news('technology')
#    Found 3 articles
#
# ✅ scrape_hacker_news()
#    Found 3 trending stories
#
# ✅ get_project_summary('Python')
#
# ✅ get_crypto_prices('BTC,ETH')
#    BTC: $66067.63
#
# ✅ generate_chart(dict)
#    URL: https://quickchart.io/chart?c=%7B%22type%22%3A%20%22bar%22%2...
#
# ======================================================================
# ✅ Tests passed: 6/6
# ======================================================================

# %% [markdown]
# ---
#
# # 🏗️ Build Your Tech Trend Discovery Agent
#
# Now it's your turn! You'll write a **system prompt** that turns a generic LLM into a tech trend analyst.
#
# ## 🎯 Your Mission
#
# Build an agent that:
# 1. Scrapes Hacker News for trending tech discussions
# 2. Identifies key themes and patterns across stories
# 3. Gathers additional context when needed
# 4. Delivers a professional trend analysis with sources
#
# ---
#
# ## 🛠️ Available Tools
#
# Tell your agent which tools to use and how. Each tool is invoked by name with a single string input:
#
# | Tool | What It Does | Action Input Example |
# |------|--------------|----------------------|
# | `scrape_hacker_news` | Top 3 trending Hacker News stories | *(no input needed)* |
# | `get_project_summary` | Web search for any topic | `LangChain AI agent framework` |
# | `get_stock_price` | Current price, change, % change | `AAPL` |
# | `search_news` | Recent news articles | `AI agents 2025 trends` |
# | `get_crypto_prices` | Cryptocurrency prices (Binance) | `BTC,ETH,SOL` |
# | `generate_chart` | Bar chart from a dict of values | `{"BTC": 65000, "ETH": 3500}` |
#
# You don't need all of them — pick the ones that make sense for tech trend discovery.

# %% [markdown]
# ---
#
# ## 💭 Prompt Engineering for Agents
#
# Before coding, design your system prompt. Great prompts are the difference between chaos and intelligence.
#
# **✅ DO:**
# - Be explicit and specific ("ALWAYS", "NEVER", "MUST")
# - Use conditional logic ("IF condition, THEN action")
# - Provide examples of desired output
# - Define step-by-step workflows
# - Specify exact format requirements
#
# **❌ DON'T:**
# - Be vague ("analyze this", "look into that")
# - Let the agent guess what to do
# - Skip output format specification
# - Forget to define stopping conditions
#
# ---
#
# **💡 Tip**: The LLM follows instructions literally. If you don't specify it, the agent won't do it!

# %%
# 🏗️ Build Your Tech Trend Discovery Agent
# Fill in the blanks in the system prompt below, then run this cell.

from lab import BaseAgent, Tools

tools = Tools()

class MyTechTrendAgent(BaseAgent):

    @property
    def system_prompt(self):
        return """You are a Professional Tech Trend Analyst specialized in discovering and analyzing emerging technology trends.

YOUR WORKFLOW (follow these steps IN ORDER):

Step 1:
   -
   -

Step 2:
   -
   -

Step 3:
   -
   -

Step 4:
   -
   -

CRITICAL RULES:
-
-
-
-

CRITICAL FORMAT RULES:
-
-
-
-

OUTPUT FORMAT (use this EXACT structure after "Final Answer:"):

## 🔥 Tech Trend Analysis: [Topic]

### 📊 Current Trending Topics

**1. [Theme Name]**
- Key point 1
- Key point 2
- [Source: HN Discussion](url)

**2. [Theme Name]**
- Key point 1
- Key point 2
- [Source: HN Discussion](url)

### 💡 Key Insights

- **Momentum**: [Growing / Stable / Declining]
- **Focus**: [What the community is discussing]
- **Community Interest**: [High / Medium / Low]

### 🎯 Trend Assessment

[2-3 sentence synthesis of the overall trend and why it matters]

---
*Analysis based on Hacker News trending discussions*

Remember: After getting all observations, start with "Final Answer:" - NEVER just output text!"""

# Create your agent
my_agent = MyTechTrendAgent(tools)
print(f"✅ Agent created — LLM: {type(my_agent.llm).__name__}")
# Out:
# 🔧 Using BedrockBridge for LLM calls
# ✅ Agent created — LLM: BedrockBridge

# %% [markdown]
# ---
#
# ## 🧪 Test Your Agent

# %%
# 🧪 Test Your Agent — change the query and re-run as many times as you like

test_query = "AI agents"  # Try: "WebAssembly", "Rust", "quantum computing", "LLMs"

print(f"📡 Discovering trends for: {test_query}...\n")
for output in my_agent.run(test_query):
    print(output)

print("-" * 70)
print("✅ Done! Did it scrape HN? Identify themes? Format correctly?")
print("💡 If not — go back and tweak your system_prompt, then re-run both cells.")
# Out:
# 📡 Discovering trends for: AI agents...
#
# Thought: I need to check Hacker News for trending AI agent discussions first.
#
# Action: scrape_hacker_news
# Action Input: unused
# Observation: [('Statement from Dario Amodei on our discussions with the Department of War', 'https://www.anthropic.com/news/statement-department-of-war'), ('F-Droid Board of Directors nominations 2026', 'https://f-droid.org/2026/02/26/board-of-directors-nominations.html'), ('Can you reverse engineer our neural network?', 'https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/')]
#
# Thought: I have the HN results, but none of them directly relate to AI agents. Let me search for more context on the Anthropic/Department of War story since it's the top story and relates to AI, and also do a quick search on AI agents trends.
#
# Action: get_project_summary
# Action Input: AI agents 2025 latest trends Hacker News
# Observation: [{'title': 'AI Adoption Trends - Ai Trends 2025 - Insights & Predictions', 'href': 'https://www.bing.com/aclick?ld=e8arEmlrjskIuH-xHmwCv7WTVUCUzGswG5SgBNvOF-qj2RIpeqpLg1oFtyEX2GxEI_ZkCr2bSvza0S1hEhROM2e9OvYE5s0Lmqn7cDUYPBmpVeQIy_yF4XhFXCmrIfuXxVEhZqf15-IYkUSkmgUTmw7TDfBF74pRrQOfYm78HkiDsUrRq0CtAjmh_Lt4AYcDnfZfzBUuuBKV0VSfThVqXmuv1LiqI&u=...&rlid=4f2a106f714c11d5cd9a79cefb02a3b4', 'body': 'Uncover AI ’s impact on productivity & workflows. Consumer Edge data Tracks AI Spending Boom and Consumer Trends'}]
#
# Final Answer: ## 🔥 Tech Trend Analysis: AI Agents
#
# ### 📊 Current Trending Topics
#
# Based on Hacker News activity and supplementary research:
#
# **1. AI & Defense/Government Collaboration**
# - Anthropic (maker of Claude AI) issued a formal statement regarding discussions with the U.S. Department of Defense
# - Signals growing intersection of AI agents and national security applications
# - Raises ethical debates around AI autonomy in high-stakes environments
# - [Source: HN Discussion](https://www.anthropic.com/news/statement-department-of-war)
#
# **2. Neural Network Interpretability & Reverse Engineering**
# - Jane Street's challenge to reverse-engineer a neural network is gaining community attention
# - Reflects rising interest in AI transparency, explainability, and agent decision-making
# - Directly relevant to understanding how AI agents "think" and make decisions
# - [Source: HN Discussion](https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/)
#
# **3. Open-Source & Privacy-First Tech (F-Droid)**
# - F-Droid governance updates signal community investment in open, auditable software
# - Ties into broader concerns about AI agent transparency and user control
# - [Source: HN Discussion](https://f-droid.org/2026/02/26/board-of-directors-nominations.html)
#
# ---
#
# ### 💡 Key Insights
#
# - **Momentum**: AI agent deployment is accelerating into sensitive domains (defense, finance), pushing interpretability to the forefront
# - **Focus**: Community attention is shifting from *building* agents to *understanding* and *governing* them
# - **Community Interest**: Medium-High — topics span ethics, security, and technical depth
#
# ---
#
# ### 🎯 Trend Assessment
#
# The AI agent conversation in 2025 is maturing beyond hype — the community is now grappling with **accountability, interpretability, and governance**. Anthropic's defense engagement and Jane Street's neural network challenge both point to a critical inflection point: as agents gain real-world power, understanding and controlling them becomes paramount.
#
# ---
# *Analysis based on Hacker News trending discussions*
#
# ----------------------------------------------------------------------
# ✅ Done! Did it scrape HN? Identify themes? Format correctly?
# 💡 If not — go back and tweak your system_prompt, then re-run both cells.

# %% [markdown]
# ---
#
# ## 🔄 Iterate and Refine
#
# Your first version won't be perfect - that's normal! Great agents are built through iteration.
#
# ### 🐛 Universal Debugging Patterns
#
# **Issue: Agent doesn't use expected tools**
# - ✅ Make tool usage explicit: "FIRST, use [tool_name]..."
# - ✅ Make it mandatory: "You MUST use [tool] to..."
# - ✅ Explain WHY to use each tool
#
# **Issue: Agent repeats the same action**
# - ✅ Add progression logic: "AFTER [action], move to [next_action]"
# - ✅ Prevent loops: "DO NOT call [tool] more than once"
# - ✅ Define clear stopping conditions
#
# **Issue: Inconsistent or poor output format**
# - ✅ Provide an exact template: "You MUST use this format:"
# - ✅ Show a concrete example in the prompt
# - ✅ Use strong language: "ALWAYS include...", "NEVER omit..."
#
# **Issue: Agent does too much or too little**
# - ✅ Add conditional logic: "IF [condition], THEN [action], ELSE [other_action]"
# - ✅ Set clear boundaries: "ONLY search news if..."
# - ✅ Define efficiency rules: "Limit to X tool calls"
#
# **Issue: Agent "forgets" previous information**
# - ✅ Add state tracking: "Keep track of all data you collect"
# - ✅ Make memory explicit: "After each step, note: [key: value]"
# - ✅ Reference previous observations: "Use the price you found earlier..."
#
# **Issue: Wrong workflow or sequencing**
# - ✅ Number your steps: "Step 1: [action]. Step 2: [action]..."
# - ✅ Be MORE explicit about the entire workflow
# - ✅ Define dependencies: "You can't do Y until you've done X"

# %% [markdown]
# ---
#
# ## 🎯 Agent Testing & Optimization
#
# Now let's test your agent with different scenarios. Each scenario tests specific capabilities:
#
# 1. **Popular Technology** - Well-discussed topic with multiple HN stories
# 2. **Niche Technology** - Less common topic with limited discussions
# 3. **Invalid/No Results** - Handling when no relevant stories found
# 4. **Broad Category** - Organizing many results into themes
#
# Each test will show:
# - ✅ Your agent's output
# - 📋 Reference example (what good output looks like)
# - ✓ Checklist for self-evaluation
#
# Run each scenario below and compare your results!

# %%
# Import testing utilities

import sys

# Clear any cached imports of the optimization module
if 'session_1_agent_optimization' in sys.modules:
    del sys.modules['session_1_agent_optimization']
    print("✅ Cleared cached optimization module")

from session_1_agent_optimization import test_scenario, get_scenario
from lab import display_react_format_error

print("✅ Testing utilities loaded. Run the scenario cells below!")
# Out:
# ✅ Testing utilities loaded. Run the scenario cells below!

# %% [markdown]
# ---
#
# ### 🔥 Scenario 1: Popular Technology Trend
#
# We are going to run a query on a popular topic to check that our agent is capable of finding news and presenting them.
#
# **What we're testing:**
# - Does the agent scrape Hacker News successfully?
# - Does it identify key themes across multiple stories?
# - Is the analysis insightful (not just listing)?
# - Are sources properly attributed?
#
# **Expected behavior:**
# 1. Call `scrape_hacker_news()` to get trending stories
# 2. Analyze patterns and themes
# 3. Optionally call `get_project_summary()` if clarification needed
# 4. Provide structured trend analysis

# %%
# 🧪 Test Scenario 1: Popular Technology Trend

import time

scenario = get_scenario("tech_trends", 1)
print(f"🎯 Testing: {scenario.name}")
print(f"📝 Suggested Query: '{scenario.query}'\n")
print("=" * 70)
print("🤖 YOUR AGENT'S OUTPUT:")
print("=" * 70)

start = time.time()
try:
    for output in my_agent.run("AI agents"):
        print(output, end='')
    duration = time.time() - start

    print(f"\n{'=' * 70}")
    print(f"⏱️  Completed in {duration:.1f}s")
    print("=" * 70)
    print("\n👇 Compare your output to the reference answer below")

except ValueError as e:
    display_react_format_error(e)
# Out:
# 🎯 Testing: Popular Technology Trend
# 📝 Suggested Query: 'AI agents'
#
# ======================================================================
# 🤖 YOUR AGENT'S OUTPUT:
# ======================================================================
# Thought: I need to check Hacker News for trending AI agent discussions first.
# Action: scrape_hacker_news
# Action Input: unused
# Observation: [('Statement from Dario Amodei on our discussions with the Department of War', 'https://www.anthropic.com/news/statement-department-of-war'), ('F-Droid Board of Directors nominations 2026', 'https://f-droid.org/2026/02/26/board-of-directors-nominations.html'), ('Can you reverse engineer our neural network?', 'https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/')]
# Thought: The HN results don't directly mention AI agents, but I can see a relevant story about Anthropic (makers of Claude AI) and a neural network reverse engineering challenge from Jane Street. Let me get more context about the Anthropic story since it's highly relevant to AI agents and the broader AI landscape.
# Action: get_project_summary
# Action Input: Anthropic Department of War AI agents military
# Observation: [{'title': 'Statement from Dario Amodei on our discussions with the Department of ...', 'href': 'https://www.anthropic.com/news/statement-department-of-war', 'body': '13 hours ago · Anthropic understands that the Department of War, not private companies, makes military decisions. We have never raised objections to ...'}]
# Final Answer: ## 🔥 Tech Trend Analysis: AI Agents
#
# ### 📊 Current Trending Topics
#
# Based on Hacker News trending discussions:
#
# **1. AI in Military & Defense (Anthropic × Department of War)**
# - Dario Amodei issued a public statement regarding Anthropic's discussions with the U.S. Department of War
# - Anthropic clarifies it does **not** make military decisions — that authority remains with the DoD
# - Signals a major shift: frontier AI companies are now actively engaging with defense institutions
# - Raises critical questions about AI agent deployment in high-stakes, autonomous military contexts
# - [Source: HN Discussion](https://www.anthropic.com/news/statement-department-of-war)
#
# **2. Neural Network Interpretability (Jane Street)**
# - Jane Street challenges the community to reverse-engineer a neural network — a rare, hands-on interpretability puzzle
# - Reflects growing interest in **understanding AI agent internals**, not just outputs
# - Directly relevant to AI agent safety and auditability
# - [Source: HN Discussion](https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/)
#
# **3. Open-Source & Privacy-First Tech (F-Droid)**
# - F-Droid governance expansion signals community push for **transparent, open alternatives** to AI-driven ecosystems
# - Indirectly tied to AI agent concerns around data privacy and centralized control
# - [Source: HN Discussion](https://f-droid.org/2026/02/26/board-of-directors-nominations.html)
#
# ---
#
# ### 💡 Key Insights
#
# - **Momentum**: AI agent deployment is accelerating into **sensitive, high-stakes domains** (defense, finance)
# - **Focus**: The community is shifting from *building* agents to *governing and understanding* them
# - **Community Interest**: High — military AI ethics and interpretability are generating significant engagement
#
# ### 🎯 Trend Assessment
#
# The AI agent conversation is maturing rapidly — moving beyond capability demos into **accountability, interpretability, and governance**. Anthropic's engagement with the Department of War marks a pivotal moment where AI agents are no longer just productivity tools but potential instruments of national security. The community is watching closely, and the pressure for transparency has never been higher.
#
# ---
# *Analysis based on Hacker News trending discussions*
#
# ======================================================================
# ⏱️  Completed in 31.3s
# ======================================================================
#
# 👇 Compare your output to the reference answer below

# %% [markdown]
# #### ✨ Reference Answer (Example)
#
# > **Note:** HN content changes constantly. Focus on comparing FORMAT, STRUCTURE, and ANALYSIS QUALITY.
#
# ```
# ## 🔥 Tech Trend Analysis: AI Agents
#
# ### 📊 Current Trending Topics
#
# Based on Hacker News activity:
#
# **1. AI Agent Frameworks & Tools**
# - New framework "LangChain" gaining traction (850 points)
# - Focus on easy integration with multiple LLMs
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=12345)
#
# **2. Production Deployment Patterns**
# - Companies sharing real-world implementations
# - Emphasis on reliability and error handling
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=67890)
#
# **3. Safety & Control Mechanisms**
# - Active debate on agent autonomy limits
# - Discussion around human-in-the-loop patterns
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=11223)
#
# ### 💡 Key Insights
#
# - **Momentum**: Strong upward trend in tooling maturity
# - **Focus**: Shifting from research to production readiness
# - **Community Interest**: High engagement (500+ points average)
#
# ### 🎯 Trend Assessment
#
# AI agents are moving from experimental phase to production adoption. The community is actively solving practical challenges around deployment, safety, and reliability.
#
# ---
# *Analysis based on Hacker News trending discussions*
# ```
#
# ---
#
# #### 📋 Evaluation Checklist
#
# **Does your agent's output match these criteria?**
#
# - ✅ Scraped Hacker News for trending stories
# - ✅ Identified 2-4 main themes/patterns
# - ✅ Included HN point scores for context
# - ✅ Provided source links to discussions
# - ✅ Synthesized insights (not just listing)
# - ✅ Clear trend assessment with reasoning
# - ✅ Professional format with sections
#
# **Self-Assessment:** Does your agent match the reference quality? ✅ / ⚠️

# %% [markdown]
# ---
#
# ### 🔍 Scenario 2: Niche Technology
#
# We are going to check how our agent behaves when prompted with a niche technology with less news coverage.
#
# **What we're testing:**
# - How does the agent handle less popular topics?
# - Does it provide useful analysis even with limited data?
# - Does it acknowledge limited HN coverage?
# - Does it use web search appropriately?
#
# **Expected behavior:**
# 1. Call `scrape_hacker_news()` first
# 2. Notice limited/no relevant HN results
# 3. Optionally use `get_project_summary()` for more context
# 4. Provide honest assessment of trend status

# %%
# 🧪 Test Scenario 2: Niche Technology

scenario = get_scenario("tech_trends", 2)
print(f"🎯 Testing: {scenario.name}")
print(f"📝 Suggested Query: '{scenario.query}'\n")
print("=" * 70)
print("🤖 YOUR AGENT'S OUTPUT:")
print("=" * 70)

start = time.time()
try:
    for output in my_agent.run("Zig programming language"):
        print(output, end='')
    duration = time.time() - start

    print(f"\n{'=' * 70}")
    print(f"⏱️  Completed in {duration:.1f}s")
    print("=" * 70)
    print("\n👇 Compare your output to the reference answer below")

except ValueError as e:
    display_react_format_error(e)
# Out:
# 🎯 Testing: Niche/Emerging Technology
# 📝 Suggested Query: 'Zig programming language'
#
# ======================================================================
# 🤖 YOUR AGENT'S OUTPUT:
# ======================================================================
# Thought: I need to check Hacker News for trending discussions about Zig programming language first.
# Action: scrape_hacker_news
# Action Input: unused
# Observation: [('Statement from Dario Amodei on our discussions with the Department of War', 'https://www.anthropic.com/news/statement-department-of-war'), ('F-Droid Board of Directors nominations 2026', 'https://f-droid.org/2026/02/26/board-of-directors-nominations.html'), ('Can you reverse engineer our neural network?', 'https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/')]
# Thought: The HN results don't directly mention Zig, but I should get more context about Zig programming language trends to provide a comprehensive analysis. Let me search for more specific information about Zig.
# Action: get_project_summary
# Action Input: Zig programming language 2025 trends updates community
# Observation: [{'title': 'Zig is the next fashionable language - The Shape of Code', 'href': 'https://shape-of-code.com/2025/02/16/zig-is-the-next-fashionable-language/', 'body': '16 Feb 2025 · The start date for Zig is four years after the start date for Rust. Not long enough for Rust to become unfashionable and need a replacement.'}]
# Final Answer: ## 🔥 Tech Trend Analysis: Zig Programming Language
#
# ### 📊 Current Trending Topics
#
# **1. Zig as an Emerging Systems Language**
# - Zig is gaining traction as a modern alternative to C and even Rust
# - Described as "the next fashionable language" — following Rust's rise in systems programming
# - Community interest growing steadily since ~2020, roughly 4 years behind Rust's adoption curve
# - [Source: Shape of Code Analysis](https://shape-of-code.com/2025/02/16/zig-is-the-next-fashionable-language/)
#
# **2. Zig vs. Rust Narrative**
# - Zig is not positioned as a Rust-killer, but as a simpler, more C-like alternative
# - Appeals to developers who find Rust's borrow checker too complex
# - Focus on **simplicity, comptime (compile-time execution), and no hidden control flow**
#
# **3. Hacker News Community Pulse**
# - While Zig didn't appear in today's top HN stories, the broader HN community has historically shown strong interest in Zig releases and tooling updates
# - Current HN top stories lean toward AI/defense (Anthropic), open-source governance (F-Droid), and ML puzzles (Jane Street)
# - [Source: HN Top Stories](https://news.ycombinator.com)
#
# ### 💡 Key Insights
#
# - **Momentum**: 📈 Growing — Zig is in its "fashionable" ascent phase as of early 2025
# - **Focus**: Low-level systems programming, C interoperability, and build tooling (Zig is also used as a C/C++ build system)
# - **Community Interest**: Medium-High — passionate niche following, not yet mainstream
#
# ### 🎯 Trend Assessment
#
# Zig is carving out a unique niche in systems programming by prioritizing **simplicity and explicitness** over Rust's safety guarantees. Its dual role as both a language and a cross-compilation build tool gives it practical utility beyond just writing Zig code. Expect continued growth in 2025, especially among C developers looking to modernize.
#
# ---
# *Analysis based on Hacker News trending discussions + web research*
#
# ======================================================================
# ⏱️  Completed in 45.1s
# ======================================================================
#
# 👇 Compare your output to the reference answer below

# %% [markdown]
# #### ✨ Reference Answer (Example)
#
# > **Note:** Focus on comparing how the agent handles LIMITED DATA and maintains useful analysis.
#
# ```
# ## 🔥 Tech Trend Analysis: Zig Programming Language
#
# ### 📊 Current Trending Topics
#
# Limited Hacker News activity for this topic currently:
#
# **1. Occasional Compiler Updates**
# - Small but dedicated community
# - Focus on systems programming niche
# - [Note: No recent trending discussions]
#
# ### 💡 Key Insights
#
# - **Momentum**: Stable but not trending
# - **Focus**: Niche systems programming community
# - **Community Interest**: Low current HN engagement
#
# ### 🎯 Trend Assessment
#
# Zig maintains a steady niche following rather than mainstream trending status. The technology is actively developed but hasn't reached the broader HN trending threshold yet. Consider monitoring for major releases or adoption announcements.
#
# ---
# *Analysis based on Hacker News trending discussions*
# ```
#
# ---
#
# #### 📋 Evaluation Checklist
#
# **Does your agent's output match these criteria?**
#
# - ✅ Acknowledged limited HN coverage honestly
# - ✅ Still provided useful context
# - ✅ Didn't fabricate data or trends
# - ✅ Explained why topic isn't trending
# - ✅ Suggested monitoring approach
# - ✅ Professional tone despite limited data
#
# **Self-Assessment:** Does your agent match the reference quality? ✅ / ⚠️

# %% [markdown]
# ---
#
# ### ⚠️ Scenario 3: No Relevant Results
#
# We are going to test how our agent behaves when it doesn't find relevant results.
#
# **What we're testing:**
# - Error handling when topic isn't on HN
# - Helpful suggestions to user
# - Graceful degradation
# - Professional communication
#
# **Expected behavior:**
# 1. Call `scrape_hacker_news()`
# 2. Notice no relevant results for query
# 3. Provide helpful explanation
# 4. Suggest alternative queries or approaches

# %%
# 🧪 Test Scenario 3: No Relevant Results

scenario = get_scenario("tech_trends", 3)
print(f"🎯 Testing: {scenario.name}")
print(f"📝 Suggested Query: '{scenario.query}'\n")
print("=" * 70)
print("🤖 YOUR AGENT'S OUTPUT:")
print("=" * 70)

start = time.time()
try:
    for output in my_agent.run("XYZ123Framework"):
        print(output, end='')
    duration = time.time() - start

    print(f"\n{'=' * 70}")
    print(f"⏱️  Completed in {duration:.1f}s")
    print("=" * 70)
    print("\n👇 Compare your output to the reference answer below")

except ValueError as e:
    display_react_format_error(e)
# Out:
# 🎯 Testing: No Results Found
# 📝 Suggested Query: 'XYZ123Framework'
#
# ======================================================================
# 🤖 YOUR AGENT'S OUTPUT:
# ======================================================================
# Thought: I need to check Hacker News for trending stories first before providing any analysis, as per my mandatory workflow.
# Action: scrape_hacker_news
# Action Input: unused
# Observation: [('Statement from Dario Amodei on our discussions with the Department of War', 'https://www.anthropic.com/news/statement-department-of-war'), ('F-Droid Board of Directors nominations 2026', 'https://f-droid.org/2026/02/26/board-of-directors-nominations.html'), ('Can you reverse engineer our neural network?', 'https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/')]
# Thought: I have the HN data. The query mentions "XYZ123Framework" which doesn't appear in the HN results. Let me check if this is a real project worth searching for, but first let me analyze what's trending. The HN stories cover Anthropic/AI policy, F-Droid open source, and a neural network reverse engineering challenge. "XYZ123Framework" doesn't match any trending topic, but I should do a quick search to see if it's a real technology.
# Action: get_project_summary
# Action Input: XYZ123Framework technology framework
# Observation: [{'title': 'Technology Modelling Overview | The Essential Project', 'href': 'https://enterprise-architecture.org/university/technology-modelling-overview/', 'body': '1 Jul 2025 · Overview of technology modelling in the technology layer of the enterprise architecture especically when using Essential.'}]
# Final Answer: ## 🔥 Tech Trend Analysis: XYZ123Framework
#
# ### 📊 Current Trending Topics
#
# Based on Hacker News activity and web research, **XYZ123Framework** does not appear to be a recognized or established technology framework. No relevant results were found on Hacker News or across the web. Here's what *is* trending right now:
#
# **1. AI & Defense Ethics (Anthropic / Dario Amodei)**
# - Anthropic's CEO issued a public statement regarding discussions with the U.S. Department of War
# - Raises significant questions about AI governance, military AI use, and corporate responsibility
# - High community relevance given Anthropic's safety-focused mission
# - [Source: HN Discussion](https://www.anthropic.com/news/statement-department-of-war)
#
# **2. Open Source Mobile Ecosystem (F-Droid)**
# - F-Droid is holding Board of Directors nominations for 2026
# - Signals active community governance in privacy-focused, open-source Android app distribution
# - Reflects growing interest in decentralized, user-controlled software ecosystems
# - [Source: HN Discussion](https://f-droid.org/2026/02/26/board-of-directors-nominations.html)
#
# **3. Neural Network Interpretability (Jane Street)**
# - Jane Street challenges the community to reverse-engineer a neural network
# - Touches on explainability, transparency, and the limits of black-box ML models
# - Strong signal of growing interest in AI interpretability research
# - [Source: HN Discussion](https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/)
#
# ---
#
# ### 💡 Key Insights
#
# - **Momentum**: AI ethics and interpretability are rapidly accelerating topics
# - **Focus**: Community attention is on *responsible AI* and *open-source governance*
# - **Community Interest**: Medium-to-High across all three stories
#
# ### 🎯 Trend Assessment
#
# **XYZ123Framework appears to be fictitious or extremely niche** — no credible sources confirm its existence. The real trending themes today center on AI accountability, open-source sustainability, and neural network transparency. These reflect a maturing tech community demanding more responsible and interpretable systems.
#
# ---
# *Analysis based on Hacker News trending discussions*
#
# ======================================================================
# ⏱️  Completed in 30.9s
# ======================================================================
#
# 👇 Compare your output to the reference answer below

# %% [markdown]
# #### ✨ Reference Answer (Example)
#
# > **Note:** Focus on comparing ERROR HANDLING, HELPFULNESS, and USER GUIDANCE.
#
# ```
# ## 🔥 Tech Trend Analysis: [Topic]
#
# ### 📊 No Trending Discussions Found
#
# I searched Hacker News but didn't find any trending discussions about this topic currently.
#
# ### 💡 Possible Reasons
#
# - **Timing**: Topic may not be trending right now
# - **Terminology**: Different terms might be used in discussions
# - **Niche Topic**: May not have mainstream HN coverage
#
# ### 🎯 Suggestions
#
# Try these alternative searches:
# - Search for related broader terms (e.g., "web framework" instead of specific name)
# - Check back later when there's more activity
# - Try searching for the company/organization behind the technology
# - Look for related trending topics in the same domain
#
# ---
# *Analysis based on Hacker News trending discussions*
# ```
#
# ---
#
# #### 📋 Evaluation Checklist
#
# **Does your agent's output match these criteria?**
#
# - ✅ Clearly communicated no results found
# - ✅ Didn't crash or produce confusing output
# - ✅ Explained possible reasons
# - ✅ Provided helpful suggestions
# - ✅ Professional, helpful tone
# - ✅ Maintained format structure
#
# **Self-Assessment:** Does your agent match the reference quality? ✅ / ⚠️

# %% [markdown]
# ---
#
# ### 📚 Scenario 4: Broad Category Analysis
#
# We are going to test how our agent behaves when it gets an overwhelming number of results.
#
# **What we're testing:**
# - Handling queries that span multiple topics
# - Organizing diverse results into themes
# - Identifying meta-patterns across discussions
# - Providing strategic overview
#
# **Expected behavior:**
# 1. Call `scrape_hacker_news()`
# 2. Find multiple diverse stories in category
# 3. Group into logical themes/subcategories
# 4. Provide high-level trend synthesis

# %%
# 🧪 Test Scenario 4: Broad Category Analysis

scenario = get_scenario("tech_trends", 4)
print(f"🎯 Testing: {scenario.name}")
print(f"📝 Suggested Query: '{scenario.query}'\n")
print("=" * 70)
print("🤖 YOUR AGENT'S OUTPUT:")
print("=" * 70)

start = time.time()
try:
    for output in my_agent.run("machine learning"):
        print(output, end='')
    duration = time.time() - start

    print(f"\n{'=' * 70}")
    print(f"⏱️  Completed in {duration:.1f}s")
    print("=" * 70)
    print("\n👇 Compare your output to the reference answer below")

except ValueError as e:
    display_react_format_error(e)
# Out:
# 🎯 Testing: Broad Technology Category
# 📝 Suggested Query: 'machine learning'
#
# ======================================================================
# 🤖 YOUR AGENT'S OUTPUT:
# ======================================================================
# Thought: I need to check Hacker News for trending machine learning discussions first.
# Action: scrape_hacker_news
# Action Input: unused
# Observation: [('Statement from Dario Amodei on our discussions with the Department of War', 'https://www.anthropic.com/news/statement-department-of-war'), ('F-Droid Board of Directors nominations 2026', 'https://f-droid.org/2026/02/26/board-of-directors-nominations.html'), ('Can you reverse engineer our neural network?', 'https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/')]
# Thought: I have the HN results. I can see a relevant story about neural networks from Jane Street. Let me get more context about this neural network reverse engineering challenge since it's directly related to machine learning.
# Action: get_project_summary
# Action Input: Jane Street reverse engineer neural network challenge machine learning
# Observation: [{'title': 'All Posts - Jane Street Blog', 'href': 'https://blog.janestreet.com/archive/', 'body': '27 Aug 2017 · Can you reverse engineer our neural network? Feb 11. Results from the Advent of FPGA Challenge. Feb 5. I design with Claude more than Figma now ...'}]
# Final Answer: ## 🔥 Tech Trend Analysis: Machine Learning
#
# ### 📊 Current Trending Topics
#
# Based on Hacker News activity:
#
# **1. Neural Network Interpretability & Reverse Engineering**
# - Jane Street posted a challenge: *"Can you reverse engineer our neural network?"*
# - Highlights growing interest in **model interpretability** — understanding what's inside black-box ML models
# - Reflects real-world demand from quantitative finance and high-stakes industries
# - [Source: HN Discussion](https://blog.janestreet.com/can-you-reverse-engineer-our-neural-network/)
#
# **2. AI in Defense & Government**
# - Anthropic (makers of Claude) issued a statement on discussions with the **Department of War**
# - Signals increasing deployment of large-scale ML/AI systems in sensitive government contexts
# - Raises ethical debates around responsible AI use in military applications
# - [Source: HN Discussion](https://www.anthropic.com/news/statement-department-of-war)
#
# **3. Open-Source ML Tooling & Governance**
# - F-Droid (open-source ecosystem) holding board nominations — reflects broader community governance trends
# - Open-source infrastructure underpins much of modern ML tooling (PyTorch, Hugging Face, etc.)
# - [Source: HN Discussion](https://f-droid.org/2026/02/26/board-of-directors-nominations.html)
#
# ---
#
# ### 💡 Key Insights
#
# - **Momentum**: ML is accelerating into **high-stakes domains** (finance, defense, government)
# - **Focus**: Community attention is shifting toward **interpretability, ethics, and governance** — not just model performance
# - **Community Interest**: Medium-High — topics span technical challenges to policy debates
#
# ---
#
# ### 🎯 Trend Assessment
#
# Machine learning is maturing beyond research labs into critical infrastructure, triggering urgent conversations about **transparency and accountability**. Jane Street's reverse-engineering challenge reflects the industry's need to understand and audit ML models. Meanwhile, Anthropic's government engagement signals that frontier AI policy is becoming inseparable from ML development itself.
#
# ---
# *Analysis based on Hacker News trending discussions*
#
# ======================================================================
# ⏱️  Completed in 31.7s
# ======================================================================
#
# 👇 Compare your output to the reference answer below

# %% [markdown]
# #### ✨ Reference Answer (Example)
#
# > **Note:** Focus on comparing ORGANIZATION, SYNTHESIS, and STRATEGIC INSIGHTS.
#
# ```
# ## 🔥 Tech Trend Analysis: Web Development
#
# ### 📊 Current Trending Topics
#
# Diverse activity across the web development landscape:
#
# **1. Framework Evolution**
# - Next.js 15 release with major performance improvements (920 points)
# - React Server Components adoption growing
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=12345)
#
# **2. Developer Experience Tools**
# - New build tools focusing on speed (Turbopack, etc.)
# - Type safety becoming standard expectation
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=67890)
#
# **3. Full-Stack Simplification**
# - Move toward monolithic frameworks
# - Database-to-UI type safety chains
# - [Source: HN Discussion](https://news.ycombinator.com/item?id=11223)
#
# ### 💡 Key Insights
#
# - **Momentum**: Rapid evolution toward integrated solutions
# - **Focus**: Developer productivity and type safety
# - **Community Interest**: Very high engagement across subcategories
#
# ### 🎯 Trend Assessment
#
# Web development is consolidating around full-stack frameworks that provide end-to-end type safety and excellent DX. The community is moving away from complex multi-tool setups toward integrated solutions.
#
# ---
# *Analysis based on Hacker News trending discussions*
# ```
#
# ---
#
# #### 📋 Evaluation Checklist
#
# **Does your agent's output match these criteria?**
#
# - ✅ Organized diverse results into clear themes
# - ✅ Identified meta-patterns across stories
# - ✅ Provided strategic overview (not just listing)
# - ✅ Connected related discussions
# - ✅ Insightful synthesis of broad category
# - ✅ Clear trend direction and implications
#
# **Self-Assessment:** Does your agent match the reference quality? ✅ / ⚠️

# %% [markdown]
# ---
#
# # 🎓 Workshop Complete!
#
# You built a **Tech Trend Discovery Agent** — nicely done!
#
# ---
#
# ### What You Practiced
#
# - 🔍 **Scraping live data** with `scrape_hacker_news`
# - 🧩 **Conditional tool use** — web search only when HN needs context
# - ✏️ **Prompt engineering** — writing instructions the LLM follows precisely
# - 📊 **Structured output** — formatting trend analysis for readability
# - 🔄 **Iterative debugging** — using test scenarios to improve your prompt
#
# ---
#
# ### Ideas to Keep Going
#
# - **Go deeper**: chain `scrape_hacker_news` → `get_project_summary` → `search_news` for multi-source analysis
# - **Add a chart**: use `generate_chart` to visualize story point scores by theme
# - **Track over time**: run the agent daily and compare trend shifts
# - **Specialize**: narrow the prompt to a single domain — AI, DevOps, security
#
# **Keep building — every great agent starts with a great prompt!** 🧠
